# %% [markdown]
# # Греческий алфавит
#
# |Заглавная|Прописная|Название|
# |:---|:---|:---|
# |A|$\alpha$|Альфа|
# |B|$\beta$|Бета|
# |$\Gamma$|$\gamma$|Гамма|
# |$\Delta$|$\delta$|Дельта|
# |E|$\epsilon$|Эпсилон|
# |Z|$\zeta$|Дзета|
# |H|$\eta$|Эта|
# |$\Theta$|$\theta$|Тета|
# |I|$\iota$|Йота|
# |K|$\kappa$|Каппа|
# |$\Lambda$|$\lambda$|Лямбда|
# |M|$\mu$|Мю|
# |N|$\nu$|Ню|
# |$\Xi$|$\xi$|Кси|
# |O|$\omicron$|Омикрон|
# |$\Pi$|$\pi$|Пи|
# |P|$\rho$|Ро|
# |$\Sigma$|$\sigma$|Сигма|
# |T|$\tau$|Тау|
# |$\Upsilon$|$\upsilon$|Ипсилон|
# |$\Phi$|$\phi$|Фи|
# |X|$\chi$|Хи|
# |$\Psi$|$\psi$|Пси|
# |$\Omega$|$\omega$|Омега|
#
# # Нормальное распределение
# Отдельной строкой
#  $$f(x)=\frac{1}{\sigma\sqrt{2\pi}}
#    e^\left(-\frac{(x-\mu)^2}{2\sigma^2}\right)$$
# В тексте $f(x)=\frac{1}{\sigma\sqrt{2\pi}}e^\left(-\frac{(x-\mu)^2}{2\sigma^2}\right)$
